# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv(
    'ElectricBill.csv', sep=",",header=0, index_col=None, usecols=None, parse_dates=['Date'])

# %%
df['Average kWh'] = df['Average kWh'].astype(float)
df.dtypes
# Out:
# Date                       datetime64[ns]
# Average kWh                       float64
# Fuel Charge (Cents/kWh)           float64
# Average Bill                      float64
# dtype: object

# %%
df.head()
# Out:
#         Date  Average kWh  Fuel Charge (Cents/kWh)  Average Bill
# 0 2000-01-01        820.0                    1.372         54.26
# 1 2000-02-01        766.0                    1.372         50.27
# 2 2000-03-01        707.0                    1.372         45.91
# 3 2000-04-01        715.0                    1.372         46.50
# 4 2000-05-01        838.0                    1.372         61.68

# %%
x1= df['Average kWh']
x2 = df['Fuel Charge (Cents/kWh)']
y = df['Average Bill']
x1= x1.values.reshape(-1,1)
x2= x2.values.reshape(-1,1)
y= y.values.reshape(-1,1)

# %%
# Normalization
scaler = MinMaxScaler()
x1 = scaler.fit_transform(x1)
x2 = scaler.fit_transform(x2)

y = scaler.fit_transform(y)

# %%
max(x2)
# Out:
# array([1.])

# %%
X = df.iloc[:, 1:3]

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

#Fitting model with trainig data
regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
pred_val = regressor.predict([[.829,0.1]])

# %%
pred_val *100
# Out:
# array([[64.00018206]])

# %%
X.head()
# Out:
#    Average kWh  Fuel Charge (Cents/kWh)
# 0     0.227979                      0.0
# 1     0.172021                      0.0
# 2     0.110881                      0.0
# 3     0.119171                      0.0
# 4     0.246632                      0.0

# %%
df['Average Bill'] = y
df['Average kWh'] = x1
df['Fuel Charge (Cents/kWh)'] = x2

# %%
df['Date'][1]
# Out:
# Timestamp('2000-02-01 00:00:00')

# %%
plt.scatter(x, y)
plt.show()

# %%
# plot bar plot with dates
# Create figure and plot space
fig, ax = plt.subplots(figsize=(10, 10))

# Add x-axis and y-axis
plt.bar(df['Date'],
        df['Average kWh'],        
        color='purple')
# Out:
# <BarContainer object of 231 artists>

# %%
plt.scatter(df['Date'], y)
plt.show()

# %%
plt.scatter(df['Date'], x)
plt.show()

# %%
df =pd.read_csv("https://www.nrc.gov/cdn/data/eventnotification/event-notification-rpt-lastmonth.txt",sep="|")
# Out:
#              Event Desc  En No                            Site Name  \
# 0         Power Reactor  55265                           Palo Verde
# 1       Agreement State  55280         MA RADIATION CONTROL PROGRAM
# 2       Agreement State  55284  TEXAS DEPT OF STATE HEALTH SERVICES
# 3       Agreement State  55292   UTAH DIVISION OF RADIATION CONTROL
# 4       Agreement State  55309     GEORGIA RADIOACTIVE MATERIAL PGM
# 5       Agreement State  55324            Ohio Department of Health
# 6   Non-Agreement State  55326                        Curium Pharma
# 7       Agreement State  55327  TEXAS DEPT OF STATE HEALTH SERVICES
# 8       Agreement State  55329       WISCONSIN RADIATION PROTECTION
# 9       Agreement State  55330       VIRGINIA RAD MATERIALS PROGRAM
# 10      Agreement State  55331  FLORIDA BUREAU OF RADIATION CONTROL
# 11      Agreement State  55332  TEXAS DEPT OF STATE HEALTH SERVICES
# 12      Agreement State  55333  TEXAS DEPT OF STATE HEALTH SERVICES
# ...
