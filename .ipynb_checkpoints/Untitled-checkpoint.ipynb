# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv(
    'ElectricBill.csv', sep=",",header=None)

# %%
df.shape
# Out:
# (232, 4)

# %%
df.tail
# Out:
# <bound method NDFrame.tail of                           0            1                        2  \
# 0                      Date  Average kWh  Fuel Charge (Cents/kWh)
# 1    01/01/2000 12:00:00 AM          820                    1.372
# 2    02/01/2000 12:00:00 AM          766                    1.372
# 3    03/01/2000 12:00:00 AM          707                    1.372
# 4    04/01/2000 12:00:00 AM          715                    1.372
# ..                      ...          ...                      ...
# 227  11/01/2018 12:00:00 AM          685                    2.895
# 228  12/01/2018 12:00:00 AM          663                    2.895
# 229  01/01/2019 12:00:00 AM          761                    2.895
# 230  02/01/2019 12:00:00 AM          707                    2.895
# 231  03/01/2019 12:00:00 AM          658                    2.895
#
#                 3
# 0    Average Bill
# 1           54.26
# 2           50.27
# 3           45.91
# 4           46.50
# ..            ...
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                 0         1                   2                    3     4
# 0    Date,Average  kWh,Fuel              Charge  (Cents/kWh),Average  Bill
# 1      01/01/2000  12:00:00  AM,820,1.372,54.26                  NaN   NaN
# 2      02/01/2000  12:00:00  AM,766,1.372,50.27                  NaN   NaN
# 3      03/01/2000  12:00:00  AM,707,1.372,45.91                  NaN   NaN
# 4      04/01/2000  12:00:00  AM,715,1.372,46.50                  NaN   NaN
# ..            ...       ...                 ...                  ...   ...
# 227    11/01/2018  12:00:00  AM,685,2.895,68.01                  NaN   NaN
# 228    12/01/2018  12:00:00  AM,663,2.895,65.67                  NaN   NaN
# 229    01/01/2019  12:00:00  AM,761,2.895,76.13                  NaN   NaN
# 230    02/01/2019  12:00:00  AM,707,2.895,70.38                  NaN   NaN
# 231    03/01/2019  12:00:00  AM,658,2.895,65.13                  NaN   NaN
#
# [232 rows x 5 columns]>

# %%
pd.isnull(df)
# Out:
#          0      1      2      3
# 0    False  False  False  False
# 1    False  False  False  False
# 2    False  False  False  False
# 3    False  False  False  False
# 4    False  False  False  False
# ..     ...    ...    ...    ...
# 227  False  False  False  False
# 228  False  False  False  False
# 229  False  False  False  False
# 230  False  False  False  False
# 231  False  False  False  False
#
# [232 rows x 4 columns]

# %%
df =pd.read_csv("https://www.nrc.gov/cdn/data/eventnotification/event-notification-rpt-lastmonth.txt",sep="|")
# Out:
#              Event Desc  En No                            Site Name  \
# 0         Power Reactor  55265                           Palo Verde
# 1       Agreement State  55280         MA RADIATION CONTROL PROGRAM
# 2       Agreement State  55284  TEXAS DEPT OF STATE HEALTH SERVICES
# 3       Agreement State  55292   UTAH DIVISION OF RADIATION CONTROL
# 4       Agreement State  55309     GEORGIA RADIOACTIVE MATERIAL PGM
# 5       Agreement State  55324            Ohio Department of Health
# 6   Non-Agreement State  55326                        Curium Pharma
# 7       Agreement State  55327  TEXAS DEPT OF STATE HEALTH SERVICES
# 8       Agreement State  55329       WISCONSIN RADIATION PROTECTION
# 9       Agreement State  55330       VIRGINIA RAD MATERIALS PROGRAM
# 10      Agreement State  55331  FLORIDA BUREAU OF RADIATION CONTROL
# 11      Agreement State  55332  TEXAS DEPT OF STATE HEALTH SERVICES
# 12      Agreement State  55333  TEXAS DEPT OF STATE HEALTH SERVICES
# ...
